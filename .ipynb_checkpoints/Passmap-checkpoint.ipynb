# %%
from statsbombpy import sb
import pandas as pd

# %%
events = sb.events(match_id=69301)

# %%
sb.competitions()[sb.competitions()['competition_name'] == 'Premier League']
# Out:
# C:\Users\rishi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id country_name competition_name  \
# 64               2         27      England   Premier League
# 65               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international  \
# 64               male              False                      False
# 65               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 64   2015/2016  2024-06-12T07:43:56.243851  2021-06-13T16:17:31.694
# 65   2003/2004  2024-03-08T14:49:13.195793  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 64                None  2024-06-12T07:43:56.243851
# 65                None  2024-03-08T14:49:13.195793

# %%
spurs_matches = matches[(matches['home_team'] == 'Tottenham Hotspur') | 
                        (matches['away_team'] == 'Tottenham Hotspur')]
print(spurs_matches.head())
# Out:
#     match_id  match_date      kick_off               competition     season  \
# 7    3754043  2016-03-20  17:00:00.000  England - Premier League  2015/2016
# 13   3754053  2016-03-13  17:00:00.000  England - Premier League  2015/2016
# 36   3754029  2015-11-02  21:00:00.000  England - Premier League  2015/2016
# 51   3754074  2015-10-04  17:00:00.000  England - Premier League  2015/2016
# 63   3754093  2015-11-29  13:00:00.000  England - Premier League  2015/2016
#
#             home_team          away_team  home_score  away_score match_status  \
# 7   Tottenham Hotspur    AFC Bournemouth           3           0    available
# 13        Aston Villa  Tottenham Hotspur           0           2    available
# 36  Tottenham Hotspur        Aston Villa           3           1    available
# 51       Swansea City  Tottenham Hotspur           2           2    available
# 63  Tottenham Hotspur            Chelsea           0           0    available
#
# ...

# %%
spurs_matches.style.set_properties(**{'background-color': '#f4f4f4', 
                                      'border': '1px solid black'}) \
             .set_table_styles([{'selector': 'th', 'props': [('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_7d1a1 th {
#   font-weight: bold;
# }
# ...

# %%
spurs_wins = spurs_matches[
    ((spurs_matches['home_team'] == 'Tottenham Hotspur') & (spurs_matches['home_score'] > spurs_matches['away_score'])) |
    ((spurs_matches['away_team'] == 'Tottenham Hotspur') & (spurs_matches['away_score'] > spurs_matches['home_score']))
]

# %%
spurs_wins.style.set_properties(**{'background-color': '#f4f4f4', 
                                      'border': '1px solid black'}) \
             .set_table_styles([{'selector': 'th', 'props': [('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_37063 th {
#   font-weight: bold;
# }
# ...

# %% [markdown]
# # SPURS WIN IN 2015/2016

# %%
print(spurs_wins[['match_date', 'home_team', 'away_team', 'home_score', 'away_score']])
# Out:
#      match_date          home_team          away_team  home_score  away_score
# 7    2016-03-20  Tottenham Hotspur    AFC Bournemouth           3           0
# 13   2016-03-13        Aston Villa  Tottenham Hotspur           0           2
# 36   2015-11-02  Tottenham Hotspur        Aston Villa           3           1
# 70   2015-12-26  Tottenham Hotspur       Norwich City           3           0
# 81   2015-09-13         Sunderland  Tottenham Hotspur           0           1
# 97   2015-12-19        Southampton  Tottenham Hotspur           0           2
# 110  2015-09-20  Tottenham Hotspur     Crystal Palace           1           0
# 114  2015-09-26  Tottenham Hotspur    Manchester City           4           1
# 131  2015-10-25    AFC Bournemouth  Tottenham Hotspur           1           5
# 138  2015-12-28            Watford  Tottenham Hotspur           1           2
# 164  2015-11-22  Tottenham Hotspur    West Ham United           4           1
# ...

# %% [markdown]
# # SPURS BIGGEST WIN

# %%
spurs_wins.loc[:, 'win_margin'] = spurs_wins['home_score'] - spurs_wins['away_score']
biggest_win = spurs_wins.loc[spurs_wins['win_margin'].idxmax()]
print(biggest_win[['match_id','match_date', 'home_team', 'away_team', 'home_score', 'away_score', 'win_margin']])
# Out:
# match_id                3754043
# match_date           2016-03-20
# home_team     Tottenham Hotspur
# away_team       AFC Bournemouth
# home_score                    3
# away_score                    0
# win_margin                    3
# Name: 7, dtype: object

# %%
df_event, df_related, df_freeze, df_tactics = parser.event(3754043)
df_event.info()
df_related.info()
df_freeze.info()
df_tactics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3752 entries, 0 to 3751
# Data columns (total 71 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3752 non-null   object
#  1   index                           3752 non-null   int64
#  2   period                          3752 non-null   int64
#  3   timestamp                       3752 non-null   object
#  4   minute                          3752 non-null   int64
#  5   second                          3752 non-null   int64
#  6   possession                      3752 non-null   int64
#  7   duration                        2736 non-null   float64
#  8   match_id                        3752 non-null   int64
#  9   type_id                         3752 non-null   int64
#  10  type_name                       3752 non-null   object
#  11  possession_team_id              3752 non-null   int64
# ...

# %% [markdown]
# # TACTICS OF SPURS (Match_id=3754043)

# %%
df_tactics.style.set_properties(**{'background-color': '#f4f4f4', 
                                      'border': '1px solid black'}) \
             .set_table_styles([{'selector': 'th', 'props': [('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_42b1c th {
#   font-weight: bold;
# }
# ...

# %%
print(df_event.head())
# Out:
#                                      id  index  period        timestamp  \
# 0  751a47eb-360b-453a-a201-2495c9ea3dff      1       1         00:00:00
# 1  f77f62b0-95df-4e6e-829e-0a27049a0ff3      2       1         00:00:00
# 2  dbbac49b-e6d1-40af-9e1c-ff14e62ee441      3       1         00:00:00
# 3  b554423d-402d-44c1-835a-56e1b93c4031      4       1         00:00:00
# 4  ff98907a-11db-4e1a-9a22-8d1a2f6f20c2      5       1  00:00:00.580000
#
#    minute  second  possession  duration  match_id  type_id    type_name  \
# 0       0       0           1  0.000000   3754043       35  Starting XI
# 1       0       0           1  0.000000   3754043       35  Starting XI
# 2       0       0           1  0.000000   3754043       18   Half Start
# 3       0       0           1  0.000000   3754043       18   Half Start
# 4       0       0           2  0.099439   3754043       30         Pass
#
#    possession_team_id possession_team_name  play_pattern_id play_pattern_name  \
# ...
